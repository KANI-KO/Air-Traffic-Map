# %%
# %pip install mplleaflet
import requests
import pandas as pd
import numpy as np
import mplleaflet
import folium
from IPython.display import display, clear_output
import time
# Out:
# Collecting mplleaflet
#   Using cached mplleaflet-0.0.5-py3-none-any.whl
# Requirement already satisfied: jinja2 in /srv/conda/lib/python3.11/site-packages (from mplleaflet) (3.1.4)
# Requirement already satisfied: six in /srv/conda/lib/python3.11/site-packages (from mplleaflet) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /srv/conda/lib/python3.11/site-packages (from jinja2->mplleaflet) (3.0.1)
# Installing collected packages: mplleaflet
# Successfully installed mplleaflet-0.0.5
# Note: you may need to restart the kernel to use updated packages.

# %%
japan_airports=pd.read_csv('japan_airports.csv', delimiter=';')
japan_airports=japan_airports[['Airport Code', 'Latitude', 'Longitude']]
japan_airports=japan_airports[japan_airports['Latitude'] > 30]
#japan_airports

# %%
# Define columns
columns = ['callsign', 'origin_country', 'long', 'lat','true_track', 'velocity','geo_altitude']
all_columns = ['icao24', 'callsign', 'origin_country', 'time_position', 'last_contact',
                   'long', 'lat', 'baro_altitude', 'on_ground', 'velocity',
                   'true_track', 'vertical_rate', 'sensors', 'geo_altitude', 'squawk', 'spi', 'position_source']

# Define Area over Japan
lon_min, lat_min=128, 30
lon_max, lat_max=149, 46

# Your OpenSkyAPI logins
user_name = '' 
password = ''

# Get flight data from OpenSkyAPI (please be mindful of the request limits)
def get_flight_data():
    url = f'https://{user_name}:{password}@opensky-network.org/api/states/all?' \
          f'lamin={lat_min}&lomin={lon_min}&lamax={lat_max}&lomax={lon_max}'
    response = requests.get(url)
    data = response.json()
    
    flights = pd.DataFrame(data['states'], columns=all_columns)[columns]
    flights = flights[~((flights['lat']>=34)&(flights['lat']<=41)&(flights['long']>=125)&(flights['long']<=130))] #exclude unneeded regions 
    flights = flights[~((flights['lat']>=42)&(flights['lat']<=49)&(flights['long']>=128)&(flights['long']<=139))] #exclude unneeded regions
    flights = flights.fillna('N/A')
    flights = flights[flights['true_track']!='N/A']

    return flights

# Create a flight map
def create_flight_map(flights):
    
    map_center = [(lat_min+lat_max)/2, (lon_min+lon_max)/2] # Center the map about the middle of Japan
    flight_map = folium.Map(location=map_center, zoom_start=5, tiles="OpenStreetMap")
    
    for _, row in flights.iterrows(): 
        
        rotation_angle = row['true_track'] 
    
        # Create a custom plane icon
        plane_icon = folium.DivIcon(f'''<div style=
        
                        "transform: rotate({rotation_angle}deg); 
                        width: 16px; 
                        height: 16px;
                        background: url('https://github.com/william-suu/Air-Traffic-Map/raw/main/plane.png') no-repeat center;
                        background-size: contain;
                        opacity: 0.8;" > </div>''')

        folium.Marker(location=[row['lat'], row['long']], 
                      popup=folium.Popup(f"""Callsign: {row['callsign']}, Origin Country: {row['origin_country']}, 
                      Velocity: {row['velocity']}, Altitude: {row['geo_altitude']}""", max_width=300), 
                      icon=plane_icon).add_to(flight_map)
        
    #Show the locations of airports in Japan
    for _, row in japan_airports.iterrows():
        folium.CircleMarker(location=[row['Latitude'], row['Longitude']], radius=3, color='red', fill=True,
        fill_color='red', fill_opacity=0.6,tooltip=row['Airport Code']).add_to(flight_map)
    
    return flight_map


end_time=time.time() + 10 # <--- total run time in seconds

while time.time() < end_time:
    
    flights = get_flight_data()
    flight_map = create_flight_map(flights)
    
    clear_output(wait=True)
    display(flight_map)
    time.sleep(5) # update the map every x number of seconds
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d881ff3ca57836906d64ca0a3d1e5756 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d881ff3ca57836906d64ca0a3d1e5756&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d881ff3ca57836906d64ca0a3d1e5756 = L.map(
#                 &quot;map_d881ff3ca57836906d64ca0a3d1e5756&quot;,
#                 {
#                     center: [38.0, 138.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8f528d9f8469866a88a0b36814854bdd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d881ff3ca57836906d64ca0a3d1e5756);
#
#
#             var marker_04d6faf40eb392ef39b9108ccb2839c0 = L.marker(
#                 [35.1731, 136.5058],
#                 {}
#             ).addTo(map_d881ff3ca57836906d64ca0a3d1e5756);
#
#
#             var div_icon_3c977ab6ba419ec1ff586065e464b7fa = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\n        \n                        \&quot;transform: rotate(254.64deg); \n                        width: 16px; \n                        height: 16px;\n                        background: url(\u0027https://github.com/william-suu/Air-Traffic-Map/raw/main/plane.png\u0027) no-repeat center;\n                        background-size: contain;\n                        opacity: 0.8;\&quot; \u003e \u003c/div\u003e&quot;});
#             marker_04d6faf40eb392ef39b9108ccb2839c0.setIcon(div_icon_3c977ab6ba419ec1ff586065e464b7fa);
#
#
#         var popup_b1801b048437cfe2267fdaf2d03abeb1 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#             var html_b8d7452dde916af964862ba96ab2626f = $(`&lt;div id=&quot;html_b8d7452dde916af964862ba96ab2626f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Callsign: ANA697  , Origin Country: Japan,                        Velocity: 188.33, Altitude: 12016.74&lt;/div&gt;`)[0];
#             popup_b1801b048437cfe2267fdaf2d03abeb1.setContent(html_b8d7452dde916af964862ba96ab2626f);
#
#
#         marker_04d6faf40eb392ef39b9108ccb2839c0.bindPopup(popup_b1801b048437cfe2267fdaf2d03abeb1)
#         ;
#
#
#
#
#             var marker_1062534eea359f3d09a3421a262fe7a8 = L.marker(
#                 [35.5367, 139.8019],
#                 {}
#             ).addTo(map_d881ff3ca57836906d64ca0a3d1e5756);
#
#
#             var div_icon_16ffc02619d7951159d52861b3293fb8 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\n        \n                        \&quot;transform: rotate(171.56deg); \n                        width: 16px; \n                        height: 16px;\n                        background: url(\u0027https://github.com/william-suu/Air-Traffic-Map/raw/main/plane.png\u0027) no-repeat center;\n                        background-size: contain;\n                        opacity: 0.8;\&quot; \u003e \u003c/div\u003e&quot;});
#             marker_1062534eea359f3d09a3421a262fe7a8.setIcon(div_icon_16ffc02619d7951159d52861b3293fb8);
#
#
#         var popup_b894c135080c54d98ee8f44f552fca32 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#             var html_9432417a3b6cc99b4f3ca66118bb7c09 = $(`&lt;div id=&quot;html_9432417a3b6cc99b4f3ca66118bb7c09&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Callsign: ANA477  , Origin Country: Japan,                        Velocity: 5.66, Altitude: N/A&lt;/div&gt;`)[0];
#             popup_b894c135080c54d98ee8f44f552fca32.setContent(html_9432417a3b6cc99b4f3ca66118bb7c09);
#
#
#         marker_1062534eea359f3d09a3421a262fe7a8.bindPopup(popup_b894c135080c54d98ee8f44f552fca32)
#         ;
#
#
#
#
#             var marker_92815c71cd6f24d04340da8c7e5e8c31 = L.marker(
#                 [35.8686, 134.2573],
#                 {}
#             ).addTo(map_d881ff3ca57836906d64ca0a3d1e5756);
#
#
#             var div_icon_43a372b0e11e081980d47afd8a8d01ba = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\n        \n                        \&quot;transform: rotate(241.35deg); \n                        width: 16px; \n                        height: 16px;\n                        background: url(\u0027https://github.com/william-suu/Air-Traffic-Map/raw/main/plane.png\u0027) no-repeat center;\n                        background-size: contain;\n                        opacity: 0.8;\&quot; \u003e \u003c/div\u003e&quot;});
#             marker_92815c71cd6f24d04340da8c7e5e8c31.setIcon(div_icon_43a372b0e11e081980d47afd8a8d01ba);
#
#
#         var popup_60edd9676043ceca468109c19eabbe53 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#             var html_dee53f5af92d4f6ba5fc7b484cc9871a = $(`&lt;div id=&quot;html_dee53f5af92d4f6ba5fc7b484cc9871a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Callsign: ANA290
